# %%
import pandas as pd
import numpy as np

df = pd.read_excel("/Users/relee/PythonProjects/JupyterNotebooks/PivotTableData.xlsx")
# df.info()
df.head()
# Out:
#             Timestamp  App ID App Name      Asn  \
# 0 2017-01-23 20:57:50   13620     amos  20115.0
# 1 2017-01-23 20:57:49   13620     amos   7922.0
# 2 2017-01-23 20:57:49   13620     amos  33363.0
# 3 2017-01-23 20:57:49   13620     amos      NaN
# 4 2017-01-23 20:57:49   13620     amos  20115.0
#
#                      Asn Organization  Backend Duration  \
# 0              Charter Communications             1.051
# 1  Comcast Cable Communications, Inc.             0.140
# 2          BRIGHT HOUSE NETWORKS, LLC             0.137
# 3                                 NaN             0.246
# 4              Charter Communications             0.001
#
#                  Browser Transaction Name       City  \
# 0                      www.avvo.com:443/*       Reno
# 1  www.avvo.com:443/professional_badges/*   Portland
# 2                 www.avvo.com:443/search    Orlando
# 3                      www.avvo.com:443/*  Bremerton
# 4  www.avvo.com:443/professional_badges/*     Fallon
#
# ...

# %%
pd.pivot_table(df,index=["Name"], values=["Count"], aggfunc="sum")
# Out:
#                                      Count
# Name
# Controller/advisor/index                 1
# Controller/answer_questions/search       3
# Controller/for_lawyers/home              1
# Controller/headshots/new                 1
# Controller/homepage/show                 1
# Controller/lawyers/search               12
# Controller/lawyers/show                 16
# Controller/legal_guides/show             1
# Controller/legal_knowledgebase/home      1
# Controller/messages/show                 1
# Controller/notifications/index           1
# Controller/professional_badges/show     48
# Controller/questions/show               10
# Controller/reviews/index                 1
# Controller/search/index                  1
# Controller/sessions/new                  1
